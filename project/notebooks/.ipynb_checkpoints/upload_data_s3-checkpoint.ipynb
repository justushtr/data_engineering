# %%
import os

s3_endpoint = os.environ.get("MLFLOW_S3_ENDPOINT_URL")
s3_access_key = os.environ.get("AWS_ACCESS_KEY_ID")
s3_secret_key = os.environ.get("AWS_SECRET_ACCESS_KEY")

# MinIO
print("MinIO endpoint:", s3_endpoint)
print("MinIO access key:", s3_access_key)
print("MinIO secret key:", s3_secret_key)
# Out:
# MinIO endpoint: http://minio.data-storage.svc.cluster.local:9000
# MinIO access key: admin
# MinIO secret key: password

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Obtaining dependency information for boto3 from https://files.pythonhosted.org/packages/8d/d1/35d12f04a7792e2f5e9ddff3c7b60493a32027761380dee7f24ee8ae80cc/boto3-1.42.36-py3-none-any.whl.metadata
#   Using cached boto3-1.42.36-py3-none-any.whl.metadata (6.8 kB)
# Collecting botocore<1.43.0,>=1.42.36 (from boto3)
#   Obtaining dependency information for botocore<1.43.0,>=1.42.36 from https://files.pythonhosted.org/packages/e6/e8/f14d25bd768187424b385bc6a44e2ed5e96964e461ba019add03e48713c7/botocore-1.42.36-py3-none-any.whl.metadata
#   Using cached botocore-1.42.36-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Obtaining dependency information for jmespath<2.0.0,>=0.7.1 from https://files.pythonhosted.org/packages/14/2f/967ba146e6d58cf6a652da73885f52fc68001525b4197effc174321d70b4/jmespath-1.1.0-py3-none-any.whl.metadata
#   Using cached jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3)
#   Obtaining dependency information for s3transfer<0.17.0,>=0.16.0 from https://files.pythonhosted.org/packages/fc/51/727abb13f44c1fcf6d145979e1535a35794db0f6e450a0cb46aa24732fe2/s3transfer-0.16.0-py3-none-any.whl.metadata
#   Using cached s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.43.0,>=1.42.36->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.43.0,>=1.42.36->boto3) (2.0.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.36->boto3) (1.16.0)
# Using cached boto3-1.42.36-py3-none-any.whl (140 kB)
# Using cached botocore-1.42.36-py3-none-any.whl (14.6 MB)
# Using cached jmespath-1.1.0-py3-none-any.whl (20 kB)
# Using cached s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.42.36 botocore-1.42.36 jmespath-1.1.0 s3transfer-0.16.0

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/62/fb/89319812eb1d714bfc04b7f177895caeba8ab4a37ef6712db75ed786e2e0/pandas-3.0.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Using cached pandas-3.0.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Obtaining dependency information for numpy>=1.26.0 from https://files.pythonhosted.org/packages/5d/9d/7862db06743f489e6a502a3b93136d73aea27d97b2cf91504f70a27501d6/numpy-2.4.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Using cached numpy-2.4.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-3.0.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 152.2 kB/s eta 0:00:0000:0100:02
# Downloading numpy-2.4.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 164.6 kB/s eta 0:00:0000:0100:03
# Installing collected packages: numpy, pandas
# Successfully installed numpy-2.4.1 pandas-3.0.0

# %%
import os
os.getcwd()
# Out:
# '/home/jovyan/data_engineering/project/notebooks'

# %%
local_filepath = "./cleaned_salesdata.csv"

# %%
import boto3
from botocore.client import Config
import pandas as pd

s3 = boto3.resource(
    's3',
    endpoint_url=s3_endpoint,
    aws_access_key_id=s3_access_key,
    aws_secret_access_key=s3_secret_key,
    config=Config(signature_version='s3v4'),
    region_name='us-east-1'
)

bucket_name = 'input-data'
if s3.Bucket(bucket_name) not in s3.buckets.all():
    s3.create_bucket(Bucket=bucket_name)
    print(f"Bucket {bucket_name} created!")
else:
    print(f"Bucket {bucket_name} already exists.")

s3.Bucket(bucket_name).upload_file(local_filepath, 'sales_data.csv')
print(f"{local_filepath.split('/')[-1]} uploaded to bucket {bucket_name}!")
# Out:
# Bucket input-data created!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 21
#      18 else:
#      19     print(f"Bucket {bucket_name} already exists.")
# ---> 21 s3.Bucket(bucket_name).upload_file(local_filepath, 'sales_data.csv')
#      22 print(f"{local_filepath.split('/')[-1]} uploaded to bucket {bucket_name}!")
#
# File /opt/conda/lib/python3.11/site-packages/boto3/s3/inject.py:266, in bucket_upload_file(self, Filename, Key, ExtraArgs, Callback, Config)
#     232 def bucket_upload_file(
#     233     self, Filename, Key, ExtraArgs=None, Callback=None, Config=None
#     234 ):
#     235     """Upload a file to an S3 object.
#     236
#     237     Usage::
#    (...)
#     264         transfer.
#     265     """
# --> 266     return self.meta.client.upload_file(
#     267         Filename=Filename,
#     268         Bucket=self.name,
#     269         Key=Key,
#     270         ExtraArgs=ExtraArgs,
#     271         Callback=Callback,
#     272         Config=Config,
#     273     )
#
# File /opt/conda/lib/python3.11/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/boto3/s3/inject.py:175, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     140 """Upload a file to an S3 object.
#     141
#     142 Usage::
#    (...)
#     172     transfer.
#     173 """
#     174 with S3Transfer(self, Config) as transfer:
# --> 175     return transfer.upload_file(
#     176         filename=Filename,
#     177         bucket=Bucket,
#     178         key=Key,
#     179         extra_args=ExtraArgs,
#     180         callback=Callback,
#     181     )
#
# File /opt/conda/lib/python3.11/site-packages/boto3/s3/transfer.py:452, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     448 future = self._manager.upload(
#     449     filename, bucket, key, extra_args, subscribers
#     450 )
#     451 try:
# --> 452     future.result()
#     453 # If a client error was raised, add the backwards compatibility layer
#     454 # that raises a S3UploadFailedError. These specific errors were only
#     455 # ever thrown for upload_parts but now can be thrown for any related
#     456 # client error.
#     457 except ClientError as e:
#
# File /opt/conda/lib/python3.11/site-packages/s3transfer/futures.py:111, in TransferFuture.result(self)
#     106 def result(self):
#     107     try:
#     108         # Usually the result() method blocks until the transfer is done,
#     109         # however if a KeyboardInterrupt is raised we want want to exit
#     110         # out of this and propagate the exception.
# --> 111         return self._coordinator.result()
#     112     except KeyboardInterrupt as e:
#     113         self.cancel()
#
# File /opt/conda/lib/python3.11/site-packages/s3transfer/futures.py:287, in TransferCoordinator.result(self)
#     284 # Once done waiting, raise an exception if present or return the
#     285 # final result.
#     286 if self._exception:
# --> 287     raise self._exception
#     288 return self._result
#
# File /opt/conda/lib/python3.11/site-packages/s3transfer/tasks.py:272, in SubmissionTask._main(self, transfer_future, **kwargs)
#     268     self._transfer_coordinator.set_status_to_running()
#     270     # Call the submit method to start submitting tasks to execute the
#     271     # transfer.
# --> 272     self._submit(transfer_future=transfer_future, **kwargs)
#     273 except BaseException as e:
#     274     # If there was an exception raised during the submission of task
#     275     # there is a chance that the final task that signals if a transfer
#    (...)
#     284
#     285     # Set the exception, that caused the process to fail.
#     286     self._log_and_set_exception(e)
#
# File /opt/conda/lib/python3.11/site-packages/s3transfer/upload.py:596, in UploadSubmissionTask._submit(self, client, config, osutil, request_executor, transfer_future, bandwidth_limiter)
#     594 # Determine the size if it was not provided
#     595 if transfer_future.meta.size is None:
# --> 596     upload_input_manager.provide_transfer_size(transfer_future)
#     598 # Do a multipart upload if needed, otherwise do a regular put object.
#     599 if not upload_input_manager.requires_multipart_upload(
#     600     transfer_future, config
#     601 ):
#
# File /opt/conda/lib/python3.11/site-packages/s3transfer/upload.py:245, in UploadFilenameInputManager.provide_transfer_size(self, transfer_future)
#     243 def provide_transfer_size(self, transfer_future):
#     244     transfer_future.meta.provide_transfer_size(
# --> 245         self._osutil.get_file_size(transfer_future.meta.call_args.fileobj)
#     246     )
#
# File /opt/conda/lib/python3.11/site-packages/s3transfer/utils.py:262, in OSUtils.get_file_size(self, filename)
#     261 def get_file_size(self, filename):
# --> 262     return os.path.getsize(filename)
#
# File <frozen genericpath>:50, in getsize(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: './notebooks/cleaned_salesdata.csv'

# %%
s3.create_bucket(Bucket="mlflow-artifacts")

# %%
for bucket in s3.buckets.all():
    print(bucket.name)

# %%
# !pip install pandas

# %%
# !pip install mlflow

# %%
# !pip install boto3
