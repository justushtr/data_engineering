# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


df = pd.read_parquet("data.parquet")

if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])

new_columns_names = ["row_id", "order_id", "ship_mode", "customer_id", "customer_name", "segment", "country", "city", "state", "postal_code", "region", "product_id", 
    "category", "sub_category", "product_name", "sales", "quantity", "discount", "profit", "order_year", "order_month", "order_day", "ship_year", "ship_month", "ship_day"]

if len(df.columns) == len(new_columns_names):
    df.columns = new_columns_names
else: 
    pass 

if "order_year" in df.columns:
    df["quantity"] = df["quantity"].astype(int)

    df["order_date"] = pd.to_datetime(
        df["order_year"].astype(str) + '-' +
        df["order_month"].astype(str) + '-' +
        df["order_day"].astype(str)             
    )

    df["order_weekday_index"] = df["order_date"].dt.weekday
    df["order_weekday"] = df["order_date"].dt.day_name()
    df["order_week_of_year"] = df["order_date"].dt.isocalendar().week
    df["order_is_weekend"] = df["order_weekday_index"] >= 5

    df["ship_date"] = pd.to_datetime(
        df["ship_year"].astype(str) + '-' +
        df["ship_month"].astype(str) + '-' +
        df["ship_day"].astype(str)             
    )
    
    df["original_price_per_unit"] = df["sales"] / (df["quantity"] * (1- df["discount"]))
    df["markdown_amount"] = (df["original_price_per_unit"] * df["quantity"]) - df["sales"]

target_col = "profit"

categorical_cols = [
    "sub_category",
    "region",
    "segment",
    "order_month"
]

numeric_cols = [
    "sales",
    "quantity",
    "original_price_per_unit",
    "markdown_amount"
]

X = df[categorical_cols + numeric_cols]
y = df[target_col]

preprocessor = ColumnTransformer(
    transformers=[
        ("num", "passthrough", numeric_cols),
        ("cat", OneHotEncoder(drop="first", sparse_output=False, dtype=int, handle_unknown="error"), categorical_cols),
    ],
    verbose_feature_names_out=False
)


def train_models_lol(random_seed):
    X_train, X_val, y_train, y_val = train_test_split(
        X, y, test_size=0.2, random_state=random_seed
    )

    print("Starte Preprocessing...")
    X_train_proc = preprocessor.fit_transform(X_train)
    X_val_proc = preprocessor.transform(X_val)
    print("Preprocessing abgeschlossen.")

    models = {
        "LinearRegression": LinearRegression(),
        "RandomForest": RandomForestRegressor(
            max_depth=20,
            min_samples_leaf = 2,
            min_samples_split = 5,
            n_estimators =500,
            random_state = 42,
            n_jobs=-1,
        ),
        "GradientBoosting": GradientBoostingRegressor(
            n_estimators=500,
            subsample=0.8,
            random_state=42,
        ),
    }

    print("\n" + "="*60)
    print(f"Random Seed: {random_seed}")
    print(f"{'Model':<20} | {'R2 Score':<10} | {'MAE':<10} | {'RMSE':<10}")
    print("="*60)

    for model_name, model in models.items():
        model.fit(X_train_proc, y_train)
        preds = model.predict(X_val_proc)

        mse = mean_squared_error(y_val, preds)
        rmse = np.sqrt(mse)
        
        mae = mean_absolute_error(y_val, preds)
        r2 = r2_score(y_val, preds)
        
        print(f"{model_name:<20} | {r2:<10.4f} | {mae:<10.2f} | {rmse:<10.2f}")

    print("="*60)

# %%
for element in [39, 40, 41, 42, 43, 44, 45, 187]:
   train_models_lol(element)
# Out:
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 39
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8446     | 36.03      | 99.83
# RandomForest         | 0.9003     | 18.72      | 79.95
# GradientBoosting     | 0.9568     | 15.74      | 52.66
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 40
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8729     | 36.46      | 89.53
# RandomForest         | 0.9339     | 16.53      | 64.54
# GradientBoosting     | 0.9381     | 15.22      | 62.48
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 41
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8238     | 36.40      | 86.42
# RandomForest         | 0.9070     | 16.58      | 62.77
# GradientBoosting     | 0.9280     | 15.41      | 55.25
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 42
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.5758     | 40.67      | 143.41
# RandomForest         | 0.2350     | 25.75      | 192.59
# GradientBoosting     | 0.5283     | 19.48      | 151.23
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 43
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.7660     | 36.96      | 85.55
# RandomForest         | 0.8537     | 17.55      | 67.64
# GradientBoosting     | 0.9200     | 14.95      | 50.01
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 44
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8473     | 38.98      | 109.06
# RandomForest         | 0.8164     | 19.85      | 119.59
# GradientBoosting     | 0.8859     | 17.47      | 94.27
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 45
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.7062     | 36.62      | 91.92
# RandomForest         | 0.7816     | 17.97      | 79.24
# GradientBoosting     | 0.9072     | 14.95      | 51.64
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 187
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.7536     | 39.97      | 120.46
# RandomForest         | 0.7797     | 20.06      | 113.90
# GradientBoosting     | 0.8497     | 17.35      | 94.08
# ============================================================

# %%
zahlen = [random.randint(1, 500) for _ in range(20)]
print(zahlen)
for element in zahlen:
   train_models_lol(element)
# Out:
# [368, 438, 331, 239, 457, 380, 380, 47, 394, 251, 51, 218, 185, 7, 44, 258, 220, 425, 112, 405]
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 368
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8514     | 35.66      | 116.53
# RandomForest         | 0.8035     | 20.08      | 134.01
# GradientBoosting     | 0.8959     | 17.06      | 97.56
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 438
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.7863     | 35.65      | 80.27
# RandomForest         | 0.8891     | 15.75      | 57.82
# GradientBoosting     | 0.9169     | 14.73      | 50.04
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 331
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8451     | 38.20      | 102.92
# RandomForest         | 0.7812     | 20.57      | 122.33
# GradientBoosting     | 0.9290     | 15.65      | 69.68
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 239
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8713     | 34.90      | 99.72
# RandomForest         | 0.8107     | 17.89      | 120.91
# GradientBoosting     | 0.8573     | 15.95      | 104.99
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 457
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8514     | 35.24      | 96.63
# RandomForest         | 0.8085     | 19.14      | 109.67
# GradientBoosting     | 0.9105     | 17.02      | 74.99
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 380
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8240     | 38.63      | 95.12
# RandomForest         | 0.8420     | 19.18      | 90.15
# GradientBoosting     | 0.9039     | 16.70      | 70.31
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 380
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8240     | 38.63      | 95.12
# RandomForest         | 0.8420     | 19.18      | 90.15
# GradientBoosting     | 0.9039     | 16.70      | 70.31
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 47
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8350     | 36.16      | 87.70
# RandomForest         | 0.9282     | 16.02      | 57.85
# GradientBoosting     | 0.9671     | 14.28      | 39.15
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 394
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8201     | 37.08      | 92.54
# RandomForest         | 0.8684     | 17.76      | 79.14
# GradientBoosting     | 0.9360     | 14.98      | 55.20
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 251
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.7759     | 38.69      | 98.06
# RandomForest         | 0.7890     | 20.85      | 95.15
# GradientBoosting     | 0.8484     | 17.34      | 80.64
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 51
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8572     | 37.83      | 106.00
# RandomForest         | 0.9021     | 20.00      | 87.75
# GradientBoosting     | 0.9411     | 17.00      | 68.05
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 218
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.7983     | 38.50      | 109.83
# RandomForest         | 0.7511     | 20.63      | 122.00
# GradientBoosting     | 0.8105     | 18.43      | 106.46
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 185
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.7538     | 40.03      | 122.20
# RandomForest         | 0.8195     | 21.07      | 104.61
# GradientBoosting     | 0.9022     | 16.32      | 76.99
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 7
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.6520     | 34.28      | 76.95
# RandomForest         | 0.8400     | 14.23      | 52.17
# GradientBoosting     | 0.9093     | 13.19      | 39.28
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 44
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8473     | 38.98      | 109.06
# RandomForest         | 0.8164     | 19.85      | 119.59
# GradientBoosting     | 0.8859     | 17.47      | 94.27
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 258
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8151     | 39.19      | 129.37
# RandomForest         | 0.7503     | 23.66      | 150.34
# GradientBoosting     | 0.8422     | 18.87      | 119.52
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 220
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.7942     | 39.88      | 112.44
# RandomForest         | 0.8370     | 20.76      | 100.06
# GradientBoosting     | 0.9439     | 16.32      | 58.70
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 425
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8759     | 36.16      | 94.64
# RandomForest         | 0.8327     | 19.83      | 109.90
# GradientBoosting     | 0.9205     | 16.84      | 75.74
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 112
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8762     | 36.07      | 103.80
# RandomForest         | 0.7724     | 20.45      | 140.74
# GradientBoosting     | 0.8415     | 18.88      | 117.44
# ============================================================
# Starte Preprocessing...
# Preprocessing abgeschlossen.
#
# ============================================================
# Random Seed: 405
# Model                | R2 Score   | MAE        | RMSE
# ============================================================
# LinearRegression     | 0.8023     | 37.91      | 91.45
# RandomForest         | 0.9086     | 17.60      | 62.16
# GradientBoosting     | 0.9217     | 16.23      | 57.53
# ============================================================
